# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import pdfplumber

# %%
#f = "//bop600/IIP-Special Projects/FATS/Redesign/PDF extraction/Python program - Kyle/TargetPDFFolderV15/000000383_Transcontinental Inc_RY2022.pdf"

# %%
#with pdfplumber.open(f) as pdf:
    #page = pdf.pages[6]
    #text = page.extract_text()

# %%
#print(text)

# %%
#pip install -i http://pypi.tunat.tsinghua.edu.can/simple paddlepaddle
import paddle

# %%
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 CPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
import os
import cv2
from paddleocr import PPStructure,draw_structure_result,save_structure_res
from paddleocr.ppstructure.recovery.recovery_to_doc import sorted_layout_boxes, convert_info_docx

# %%
table_engine = PPStructure(show_log=True, lang='en')
# Out:
# [2024/04/22 11:11:11] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\xyuchen/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\xyuchen/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...

# %%
save_folder = '//bop600/IIP-Special Projects/FATS/Redesign/PDF extraction/Python program - Kyle/TargetPDFFolderV15/output/'
img_path = "//bop600/IIP-Special Projects/FATS/Redesign/PDF extraction/Python program - Kyle/TargetPDFFolderV15/pages_keywords/"

# %%
img_files = [f for f in os.listdir(img_path) if f.endswith('.jpg')]

# %%
for imgs in img_files:
    print(os.path.join(img_path, imgs))
    img = cv2.imread(os.path.join(img_path, imgs))

    result = table_engine(img)

    #save_structure_res(result, save_folder,os.path.basename(os.path.join(img_path, imgs)).split('.')[0])

    for line in result:
        line.pop('img')
        #print(line)

    h, w, _ = img.shape
    res = sorted_layout_boxes(result, w)
    convert_info_docx(img, res, save_folder, imgs)
# Out:
# //bop600/IIP-Special Projects/FATS/Redesign/PDF extraction/Python program - Kyle/TargetPDFFolderV15/pages_keywords/000001161_Royal Bank of Canada_RY2022.pdfoutput93.jpg
# [2024/04/22 11:11:15] ppocr DEBUG: dt_boxes num : 12, elapsed : 0.2699291706085205
# [2024/04/22 11:11:35] ppocr DEBUG: rec_res num  : 12, elapsed : 20.113551139831543
# [2024/04/22 11:11:36] ppocr DEBUG: dt_boxes num : 9, elapsed : 0.1806035041809082
# [2024/04/22 11:11:50] ppocr DEBUG: rec_res num  : 9, elapsed : 14.17335057258606
# [2024/04/22 11:11:50] ppocr DEBUG: dt_boxes num : 7, elapsed : 0.180985689163208
# [2024/04/22 11:12:02] ppocr DEBUG: rec_res num  : 7, elapsed : 11.826611042022705
# [2024/04/22 11:12:02] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.10614562034606934
# [2024/04/22 11:12:11] ppocr DEBUG: rec_res num  : 5, elapsed : 9.281262636184692
# [2024/04/22 11:12:11] ppocr DEBUG: dt_boxes num : 5, elapsed : 0.10980224609375
# ...
