# %%
import os
import cv2
from paddleocr import PPStructure,draw_structure_result,save_structure_res

table_engine = PPStructure(show_log=True, image_orientation=True)

save_folder = ''
img_path = 'table.jpg'
img = cv2.imread(img_path)
result = table_engine(img)
save_structure_res(result, save_folder,os.path.basename(img_path).split('.')[0])

for line in result:
    line.pop('img')
    print(line)

from PIL import Image

font_path = 'simfang.ttf' # PaddleOCR下提供字体包
image = Image.open(img_path).convert('RGB')
im_show = draw_structure_result(image, result,font_path=font_path)
im_show = Image.fromarray(im_show)
im_show.save('result.jpg')
# Out:
# [2024/04/10 21:08:45] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Eric/.paddleocr/whl\\det\\ch\\ch_PP-OCRv4_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Eric/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\Eric\\anaconda3\\envs\\env1\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=False, cls_model_dir=None, cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir='C:\\Users\\Eric/.paddleocr/whl\\table\\ch_ppstructure_mobile_v2.0_SLANet_infer', merge_no_span_structure=True, table_char_dict_path='c:\\Users\\Eric\\anaconda3\\envs\\env1\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\dict\\table_structure_dict_ch.txt', layout_model_dir='C:\\Users\\Eric/.paddleocr/whl\\layout\\picodet_lcnet_x1_0_fgd_layout_cdla_infer', layout_dict_path='c:\\Users\\Eric\\anaconda3\\envs\\env1\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\dict\\layout_dict\\layout_cdla_dict.txt', layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=True, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='ch', det=True, rec=True, type='ocr', ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2024/04/10 21:08:45] ppcls INFO: download https://paddleclas.bj.bcebos.com/models/PULC/inference/text_image_orientation_infer.tar to C:\Users\Eric/.paddleclas/inference_model\PULC\text_image_orientation\text_image_orientation_infer.tar
# 100%|██████████| 7.40M/7.40M [00:07<00:00, 937kiB/s]
# [2024/04/10 21:08:55] ppcls WARNING: The current running environment does not support the use of GPU. CPU has been used instead.
# [2024/04/10 21:09:01] ppocr DEBUG: dt_boxes num : 75, elapse : 0.5327198505401611
# [2024/04/10 21:09:04] ppocr DEBUG: rec_res num  : 75, elapse : 2.9136807918548584
# {'type': 'table', 'bbox': [6, 0, 365, 290], 'res': {'cell_bbox': [[9.73599910736084, 1.3347021341323853, 144.3253936767578, 1.4133788347244263, 142.02809143066406, 19.10188865661621, 9.333357810974121, 18.614112854003906], [126.80720520019531, 1.3522288799285889, 194.2167205810547, 1.3854349851608276, 193.88645935058594, 21.692960739135742, 126.22772216796875, 21.708850860595703], [193.0455322265625, 1.2759212255477905, 250.68307495117188, 1.3202310800552368, 250.8148651123047, 21.066028594970703, 192.39561462402344, 21.174861907958984], [253.9356231689453, 1.6650733947753906, 316.139892578125, 1.730315089225769, 316.42474365234375, 20.860857009887695, 254.5359649658203, 20.818099975585938], [302.2669982910156, 1.9099361896514893, 354.76666259765625, 2.010986804962158, 354.7013244628906, 20.821144104003906, 302.32769775390625, 20.58110809326172], [10.788318634033203, 18.442550659179688, 131.32635498046875, 18.54920196533203, 130.41226196289062, 39.28038787841797, 10.452327728271484, 38.85625457763672], [131.96705627441406, 17.10205078125, 198.9551239013672, 17.505260467529297, 197.80406188964844, 47.153961181640625, 130.63650512695312, 46.33317565917969], [179.39295959472656, 16.730300903320312, 248.97703552246094, 17.02074432373047, 248.1142578125, 40.876678466796875, 177.608642578125, 40.53345489501953], [239.92465209960938, 17.266103744506836, 301.2398681640625, 17.509788513183594, 300.69097900390625, 40.436805725097656, 239.21719360351562, 40.09695816040039], [305.83209228515625, 17.381301879882812, 353.6307678222656, 17.795663833618164, 353.5277099609375, 39.84568405151367, 305.3992614746094, 39.329010009765625], [6.510725975036621, 37.726131439208984, 127.99337768554688, 38.132991790771484, 126.76661682128906, 56.26640701293945, 6.320183277130127, 55.68893814086914], [133.18453979492188, 36.40264129638672, 204.39566040039062, 37.11320495605469, 202.6865234375, 66.05421447753906, 131.4818878173828, 65.10674285888672], [182.27699279785156, 36.245174407958984, 249.3175048828125, 36.53112030029297, 248.11378479003906, 57.52663803100586, 180.34765625, 57.25732421875], [241.68545532226562, 36.69001007080078, 302.6875305175781, 37.0272331237793, 301.9941101074219, 56.839271545410156, 240.70529174804688, 56.39229965209961], [307.76129150390625, 36.80007553100586, 353.33905029296875, 37.37930679321289, 353.2154846191406, 57.08377456665039, 307.1889953613281, 56.365718841552734], [5.439694881439209, 55.77616500854492, 131.80862426757812, 56.5635986328125, 130.34561157226562, 75.29257202148438, 5.272150039672852, 74.35546875], [132.93252563476562, 54.236351013183594, 205.97413635253906, 55.27724075317383, 203.8375701904297, 83.67015075683594, 130.87364196777344, 82.52657318115234], [185.67259216308594, 54.225563049316406, 251.40431213378906, 54.69124221801758, 249.8044891357422, 75.5771484375, 183.4278106689453, 75.18575286865234], [243.49693298339844, 54.70991516113281, 302.2481384277344, 55.149879455566406, 301.4790344238281, 75.08776092529297, 242.2807159423828, 74.60643005371094], [309.498291015625, 55.107810974121094, 352.97357177734375, 55.77811813354492, 352.83770751953125, 75.22419738769531, 308.86016845703125, 74.4964828491211], [6.394282341003418, 72.70689392089844, 130.94454956054688, 73.89603424072266, 129.04855346679688, 93.99876403808594, 6.135219097137451, 92.6768569946289], [132.61770629882812, 70.79549407958984, 207.6142578125, 72.01097869873047, 205.35235595703125, 98.99331665039062, 130.22779846191406, 97.83187103271484], [185.78250122070312, 70.28101348876953, 252.60476684570312, 70.97610473632812, 250.9138946533203, 92.13190460205078, 183.2272491455078, 91.64573669433594], [244.3014373779297, 70.8514175415039, 301.7544250488281, 71.47614288330078, 300.8498229980469, 91.76408386230469, 242.87281799316406, 91.16710662841797], [310.4926452636719, 71.77920532226562, 352.2494812011719, 72.6402587890625, 352.07745361328125, 91.94878387451172, 309.7055969238281, 91.13275909423828], [7.634706974029541, 89.1017150878906 ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 21
#      19 font_path = 'doc/fonts/simfang.ttf' # PaddleOCR下提供字体包
#      20 image = Image.open(img_path).convert('RGB')
# ---> 21 im_show = draw_structure_result(image, result,font_path=font_path)
#      22 im_show = Image.fromarray(im_show)
#      23 im_show.save('result.jpg')
#
# File c:\Users\Eric\anaconda3\envs\env1\Lib\site-packages\paddleocr\ppstructure\utility.py:136, in draw_structure_result(image, result, font_path)
#     134 catid2color = {}
#     135 font_size = 15
# --> 136 font = ImageFont.truetype(font_path, font_size, encoding="utf-8")
#     138 for region in result:
#     139     if region['type'] not in catid2color:
#
# File c:\Users\Eric\anaconda3\envs\env1\Lib\site-packages\PIL\ImageFont.py:819, in truetype(font, size, index, encoding, layout_engine)
#     816     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     818 try:
# --> 819     return freetype(font)
#     820 except OSError:
#     821     if not is_path(font):
#
# File c:\Users\Eric\anaconda3\envs\env1\Lib\site-packages\PIL\ImageFont.py:816, in truetype.<locals>.freetype(font)
#     815 def freetype(font):
# --> 816     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File c:\Users\Eric\anaconda3\envs\env1\Lib\site-packages\PIL\ImageFont.py:245, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     243                 load_from_bytes(f)
#     244             return
# --> 245     self.font = core.getfont(
#     246         font, size, index, encoding, layout_engine=layout_engine
#     247     )
#     248 else:
#     249     load_from_bytes(font)
#
# OSError: cannot open resource
